# %%
import pandas as pd
import xlwings as xw

# %% [markdown]
# # pandas uses xlrd to read Excel files

# %%
df = pd.read_excel('AAPL.xlsx', index_col='Date')
df

# %% [markdown]
# # df.to_excel() uses XlsxWriter or OpenPyXL

# %%
df.to_excel('AAPL.xlsx')

# %% [markdown]
# # xlwings view function

# %%
# View the data in Excel
xw.view(df)

# %% [markdown]
# # xlwings API

# %%
# Create a new Excel workbook
wb = xw.Book()

# %%
# Write a DataFrame
wb.sheets[0]['A1'].value = df

# %%
# Read a DataFrame
wb.sheets[0]['A1'].options(pd.DataFrame, expand='table').value
